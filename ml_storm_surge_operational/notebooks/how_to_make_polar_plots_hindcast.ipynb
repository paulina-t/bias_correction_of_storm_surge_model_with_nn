# %% [markdown]
# This is a tutorial for how to make polar plots.

# %%
import numpy as np
import datetime as dt
import pickle
import matplotlib.pyplot as plt

import ml_storm_surge_operational.utils.helpers as hlp
from ml_storm_surge_operational.utils.eda import EDA
#from ml_storm_surge_operational.data_loader.prepare_df_operational import PrepareDataFrames 
from ml_storm_surge_operational.data_loader.prepare_df import PrepareDataFrames 
from ml_storm_surge_operational.utils.correct_roms_using_radial_plots import CorrectROMS
# Out:
# Put the interpreter in UTC, to make sure no TZ issues...
# Put the interpreter in UTC, to make sure no TZ issues...
# Put the interpreter in UTC, to make sure no TZ issues...

# %%
# %matplotlib inline

# %%
variables = [
    'obs', 'tide_py', 'roms', 'msl', 'u10', 'v10', 
    #'stormsurge_corrected', 
    #'bias', 
    'wind_speed', 'wind_dir', 
    'roms - (obs - tide_py)', 
    '(obs - tide_py)',
    '(roms - biasMET) - (obs - tide_py)', '(roms - biasMET)'
    ]
stations = ['NO_OSC']
datetime_start_hourly = dt.datetime(2018, 1, 1, 0, 0, 0, tzinfo=dt.timezone.utc) #2001
datetime_end_hourly = dt.datetime(2019, 12, 31, 0, 0, 0, tzinfo=dt.timezone.utc)
roms_hind_var = '(roms - biasMET)'
roms_oper_var = 'stormsurge_corrected'
obs_var = '(obs - tide_py)'

# %% [markdown]
# # NORA3ERA5

# %%
prep = PrepareDataFrames(
    variables = variables,
    stations = stations,
    datetime_start_hourly = datetime_start_hourly,
    datetime_end_hourly = datetime_end_hourly,
    #use_station_data = True,
    #run_on_ppi = True,
    #new_station_loc=True,
    #era5_forcing=False,
    #add_aux_variables=False,
    horizon=1
    )

# %%
df = prep.prepare_features_labels_df()
print(df.columns)
print(df.head())
# Out:
# Preparing auxiliary DataFrame...
# list_all_variables:  ['obs', 'roms', 'u10', '(obs - tide_py)', 'tide_py', '(roms - biasMET)', 'v10']
# Generating obs and tide_py DataFrame...
# Using already generated kyststasjoner file.
# oper_df:                             tide_py_NO_OSC  obs_NO_OSC
# 2018-01-01 00:00:00+00:00            0.73        0.88
# 2018-01-01 01:00:00+00:00            0.78        0.92
# 2018-01-01 02:00:00+00:00            0.82        0.96
# 2018-01-01 03:00:00+00:00            0.85        0.93
# 2018-01-01 04:00:00+00:00            0.82        0.86
# ...                                   ...         ...
# 2019-12-30 20:00:00+00:00            0.80        1.15
# 2019-12-30 21:00:00+00:00            0.76        1.11
# 2019-12-30 22:00:00+00:00            0.70        1.03
# 2019-12-30 23:00:00+00:00            0.65        0.98
# 2019-12-31 00:00:00+00:00            0.60        0.92
#
# [17221 rows x 2 columns]
# Load all data to memory at initialization, this may take a few seconds...
# crrt_df:                             obs_NO_OSC  tide_py_NO_OSC
# 2018-01-01 00:00:00+00:00       0.879        0.720640
# 2018-01-01 01:00:00+00:00       0.920        0.770725
# 2018-01-01 02:00:00+00:00       0.955        0.822309
# 2018-01-01 03:00:00+00:00       0.928        0.871667
# 2018-01-01 04:00:00+00:00       0.855        0.868962
# ...                               ...             ...
# 2019-12-30 20:00:00+00:00       1.155        0.849811
# 2019-12-30 21:00:00+00:00       1.111        0.825735
# 2019-12-30 22:00:00+00:00       1.036        0.769728
# 2019-12-30 23:00:00+00:00       0.978        0.715371
# 2019-12-31 00:00:00+00:00       0.927        0.669125
#
# [17497 rows x 2 columns]
# station:  NO_OSC  horizon:  1
# Added obs and tide data:
#                            obs_NO_OSC  tide_py_NO_OSC
# 2018-01-01 00:00:00+00:00       0.879        0.720640
# 2018-01-01 01:00:00+00:00       0.920        0.770725
# 2018-01-01 02:00:00+00:00       0.955        0.822309
# 2018-01-01 03:00:00+00:00       0.928        0.871667
# 2018-01-01 04:00:00+00:00       0.855        0.868962
# ...                               ...             ...
# 2019-12-30 20:00:00+00:00       1.155        0.849811
# 2019-12-30 21:00:00+00:00       1.111        0.825735
# 2019-12-30 22:00:00+00:00       1.036        0.769728
# 2019-12-30 23:00:00+00:00       0.978        0.715371
# 2019-12-31 00:00:00+00:00       0.927        0.669125
#
# [17497 rows x 2 columns]
# self.df_obs_tide in add_os_tide:                             obs_NO_OSC  tide_py_NO_OSC
# 2018-01-01 00:00:00+00:00       0.879        0.720640
# 2018-01-01 01:00:00+00:00       0.920        0.770725
# 2018-01-01 02:00:00+00:00       0.955        0.822309
# 2018-01-01 03:00:00+00:00       0.928        0.871667
# 2018-01-01 04:00:00+00:00       0.855        0.868962
# ...                               ...             ...
# 2019-12-30 20:00:00+00:00       1.155        0.849811
# 2019-12-30 21:00:00+00:00       1.111        0.825735
# 2019-12-30 22:00:00+00:00       1.036        0.769728
# 2019-12-30 23:00:00+00:00       0.978        0.715371
# 2019-12-31 00:00:00+00:00       0.927        0.669125
#
# [17497 rows x 2 columns]
# Adding (obs - tide_py) columns...
# Added (obs-tide) data
#                            (obs - tide_py)_NO_OSC
# 2018-01-01 00:00:00+00:00                0.158360
# 2018-01-01 01:00:00+00:00                0.149275
# 2018-01-01 02:00:00+00:00                0.132691
# 2018-01-01 03:00:00+00:00                0.056333
# 2018-01-01 04:00:00+00:00               -0.013962
# ...                                           ...
# 2019-12-30 20:00:00+00:00                0.305189
# 2019-12-30 21:00:00+00:00                0.285265
# 2019-12-30 22:00:00+00:00                0.266272
# 2019-12-30 23:00:00+00:00                0.262629
# 2019-12-31 00:00:00+00:00                0.257875
#
# [17497 rows x 1 columns]
# dfs:  [                           obs_NO_OSC  tide_py_NO_OSC
# 2018-01-01 00:00:00+00:00       0.879        0.720640
# 2018-01-01 01:00:00+00:00       0.920        0.770725
# 2018-01-01 02:00:00+00:00       0.955        0.822309
# 2018-01-01 03:00:00+00:00       0.928        0.871667
# 2018-01-01 04:00:00+00:00       0.855        0.868962
# ...                               ...             ...
# 2019-12-30 20:00:00+00:00       1.155        0.849811
# 2019-12-30 21:00:00+00:00       1.111        0.825735
# 2019-12-30 22:00:00+00:00       1.036        0.769728
# 2019-12-30 23:00:00+00:00       0.978        0.715371
# 2019-12-31 00:00:00+00:00       0.927        0.669125
#
# [17497 rows x 2 columns],                            (obs - tide_py)_NO_OSC
# 2018-01-01 00:00:00+00:00                0.158360
# 2018-01-01 01:00:00+00:00                0.149275
# 2018-01-01 02:00:00+00:00                0.132691
# 2018-01-01 03:00:00+00:00                0.056333
# 2018-01-01 04:00:00+00:00               -0.013962
# ...                                           ...
# 2019-12-30 20:00:00+00:00                0.305189
# 2019-12-30 21:00:00+00:00                0.285265
# 2019-12-30 22:00:00+00:00                0.266272
# 2019-12-30 23:00:00+00:00                0.262629
# 2019-12-31 00:00:00+00:00                0.257875
#
# [17497 rows x 1 columns]]
# Generating ROMS hindcast DataFrame...
# Added hindcast data:
#                            roms_NO_OSC
# time
# 2018-01-01 00:00:00+00:00     0.411663
# 2018-01-01 01:00:00+00:00     0.555702
# 2018-01-01 02:00:00+00:00     0.474306
# 2018-01-01 03:00:00+00:00     0.263965
# 2018-01-01 04:00:00+00:00     0.255458
# ...                                ...
# 2019-12-30 20:00:00+00:00     0.353680
# 2019-12-30 21:00:00+00:00     0.454468
# 2019-12-30 22:00:00+00:00     0.438253
# 2019-12-30 23:00:00+00:00     0.336164
# 2019-12-31 00:00:00+00:00     0.356973
#
# [17497 rows x 1 columns]
# Added meteorological data...
# Generating station forcing df...
# Added station forcing data:
#                            v10_NO_OSC  u10_NO_OSC
# time
# 2018-01-01 00:00:00+00:00    0.008046   -1.591091
# 2018-01-01 01:00:00+00:00    1.154886   -1.646257
# 2018-01-01 02:00:00+00:00    2.671098   -0.772317
# 2018-01-01 03:00:00+00:00    2.987844   -0.220661
# 2018-01-01 04:00:00+00:00    3.251965   -0.152914
# ...                               ...         ...
# 2019-12-30 20:00:00+00:00    1.913973    1.409484
# 2019-12-30 21:00:00+00:00    1.939072    1.316671
# 2019-12-30 22:00:00+00:00    1.835891    2.289390
# 2019-12-30 23:00:00+00:00    1.675077    2.457727
# 2019-12-31 00:00:00+00:00    1.147088    2.930893
#
# [16968 rows x 2 columns]
# Duplicated indices in df_obs_tide:  <bound method Index.duplicated of DatetimeIndex(['2018-01-01 00:00:00+00:00', '2018-01-01 01:00:00+00:00',
#                '2018-01-01 02:00:00+00:00', '2018-01-01 03:00:00+00:00',
#                '2018-01-01 04:00:00+00:00', '2018-01-01 05:00:00+00:00',
#                '2018-01-01 06:00:00+00:00', '2018-01-01 07:00:00+00:00',
#                '2018-01-01 08:00:00+00:00', '2018-01-01 09:00:00+00:00',
#                ...
#                '2019-12-30 15:00:00+00:00', '2019-12-30 16:00:00+00:00',
#                '2019-12-30 17:00:00+00:00', '2019-12-30 18:00:00+00:00',
#                '2019-12-30 19:00:00+00:00', '2019-12-30 20:00:00+00:00',
#                '2019-12-30 21:00:00+00:00', '2019-12-30 22:00:00+00:00',
#                '2019-12-30 23:00:00+00:00', '2019-12-31 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', length=17497, freq='H')>
# Added (hindcast - biasMET) data:
#                            (roms - biasMET)_NO_OSC
# time
# 2018-01-01 00:00:00+00:00                      NaN
# 2018-01-01 01:00:00+00:00                      NaN
# 2018-01-01 02:00:00+00:00                      NaN
# 2018-01-01 03:00:00+00:00                      NaN
# 2018-01-01 04:00:00+00:00                      NaN
# ...                                            ...
# 2019-12-30 20:00:00+00:00                 0.201782
# 2019-12-30 21:00:00+00:00                 0.305189
# 2019-12-30 22:00:00+00:00                 0.290741
# 2019-12-30 23:00:00+00:00                 0.188389
# 2019-12-31 00:00:00+00:00                 0.208885
#
# [17497 rows x 1 columns]
# Print each element in dfs list:
# 0
#                            obs_NO_OSC  tide_py_NO_OSC
# 2018-01-01 00:00:00+00:00       0.879        0.720640
# 2018-01-01 01:00:00+00:00       0.920        0.770725
# 2018-01-01 02:00:00+00:00       0.955        0.822309
# 2018-01-01 03:00:00+00:00       0.928        0.871667
# 2018-01-01 04:00:00+00:00       0.855        0.868962
# ...                               ...             ...
# 2019-12-30 20:00:00+00:00       1.155        0.849811
# 2019-12-30 21:00:00+00:00       1.111        0.825735
# 2019-12-30 22:00:00+00:00       1.036        0.769728
# 2019-12-30 23:00:00+00:00       0.978        0.715371
# 2019-12-31 00:00:00+00:00       0.927        0.669125
#
# [17497 rows x 2 columns]
# 1
#                            (obs - tide_py)_NO_OSC
# 2018-01-01 00:00:00+00:00                0.158360
# 2018-01-01 01:00:00+00:00                0.149275
# 2018-01-01 02:00:00+00:00                0.132691
# 2018-01-01 03:00:00+00:00                0.056333
# 2018-01-01 04:00:00+00:00               -0.013962
# ...                                           ...
# 2019-12-30 20:00:00+00:00                0.305189
# 2019-12-30 21:00:00+00:00                0.285265
# 2019-12-30 22:00:00+00:00                0.266272
# 2019-12-30 23:00:00+00:00                0.262629
# 2019-12-31 00:00:00+00:00                0.257875
#
# [17497 rows x 1 columns]
# 2
#                            roms_NO_OSC
# time
# 2018-01-01 00:00:00+00:00     0.411663
# 2018-01-01 01:00:00+00:00     0.555702
# 2018-01-01 02:00:00+00:00     0.474306
# 2018-01-01 03:00:00+00:00     0.263965
# 2018-01-01 04:00:00+00:00     0.255458
# ...                                ...
# 2019-12-30 20:00:00+00:00     0.353680
# 2019-12-30 21:00:00+00:00     0.454468
# 2019-12-30 22:00:00+00:00     0.438253
# 2019-12-30 23:00:00+00:00     0.336164
# 2019-12-31 00:00:00+00:00     0.356973
#
# [17497 rows x 1 columns]
# 3
#                            v10_NO_OSC  u10_NO_OSC
# time
# 2018-01-01 00:00:00+00:00    0.008046   -1.591091
# 2018-01-01 01:00:00+00:00    1.154886   -1.646257
# 2018-01-01 02:00:00+00:00    2.671098   -0.772317
# 2018-01-01 03:00:00+00:00    2.987844   -0.220661
# 2018-01-01 04:00:00+00:00    3.251965   -0.152914
# ...                               ...         ...
# 2019-12-30 20:00:00+00:00    1.913973    1.409484
# 2019-12-30 21:00:00+00:00    1.939072    1.316671
# 2019-12-30 22:00:00+00:00    1.835891    2.289390
# 2019-12-30 23:00:00+00:00    1.675077    2.457727
# 2019-12-31 00:00:00+00:00    1.147088    2.930893
#
# [16968 rows x 2 columns]
# 4
#                            (roms - biasMET)_NO_OSC
# time
# 2018-01-01 00:00:00+00:00                      NaN
# 2018-01-01 01:00:00+00:00                      NaN
# 2018-01-01 02:00:00+00:00                      NaN
# 2018-01-01 03:00:00+00:00                      NaN
# 2018-01-01 04:00:00+00:00                      NaN
# ...                                            ...
# 2019-12-30 20:00:00+00:00                 0.201782
# 2019-12-30 21:00:00+00:00                 0.305189
# 2019-12-30 22:00:00+00:00                 0.290741
# 2019-12-30 23:00:00+00:00                 0.188389
# 2019-12-31 00:00:00+00:00                 0.208885
#
# [17497 rows x 1 columns]
# df:                             obs_NO_OSC  tide_py_NO_OSC
# 2018-01-01 00:00:00+00:00       0.879        0.720640
# 2018-01-01 01:00:00+00:00       0.920        0.770725
# 2018-01-01 02:00:00+00:00       0.955        0.822309
# 2018-01-01 03:00:00+00:00       0.928        0.871667
# 2018-01-01 04:00:00+00:00       0.855        0.868962
# ...                               ...             ...
# 2019-12-30 20:00:00+00:00       1.155        0.849811
# 2019-12-30 21:00:00+00:00       1.111        0.825735
# 2019-12-30 22:00:00+00:00       1.036        0.769728
# 2019-12-30 23:00:00+00:00       0.978        0.715371
# 2019-12-31 00:00:00+00:00       0.927        0.669125
#
# [17497 rows x 2 columns]
# df:                             obs_NO_OSC  tide_py_NO_OSC  (obs - tide_py)_NO_OSC  \
# 2018-01-01 00:00:00+00:00       0.879        0.720640                0.158360
# 2018-01-01 01:00:00+00:00       0.920        0.770725                0.149275
# 2018-01-01 02:00:00+00:00       0.955        0.822309                0.132691
# 2018-01-01 03:00:00+00:00       0.928        0.871667                0.056333
# 2018-01-01 04:00:00+00:00       0.855        0.868962               -0.013962
# ...                               ...             ...                     ...
# 2019-12-30 20:00:00+00:00       1.155        0.849811                0.305189
# 2019-12-30 21:00:00+00:00       1.111        0.825735                0.285265
# 2019-12-30 22:00:00+00:00       1.036        0.769728                0.266272
# 2019-12-30 23:00:00+00:00       0.978        0.715371                0.262629
# 2019-12-31 00:00:00+00:00       0.927        0.669125                0.257875
#
#                            roms_NO_OSC  v10_NO_OSC  u10_NO_OSC  \
# 2018-01-01 00:00:00+00:00     0.411663    0.008046   -1.591091
# 2018-01-01 01:00:00+00:00     0.555702    1.154886   -1.646257
# 2018-01-01 02:00:00+00:00     0.474306    2.671098   -0.772317
# 2018-01-01 03:00:00+00:00     0.263965    2.987844   -0.220661
# 2018-01-01 04:00:00+00:00     0.255458    3.251965   -0.152914
# ...                                ...         ...         ...
# 2019-12-30 20:00:00+00:00     0.353680    1.913973    1.409484
# 2019-12-30 21:00:00+00:00     0.454468    1.939072    1.316671
# 2019-12-30 22:00:00+00:00     0.438253    1.835891    2.289390
# 2019-12-30 23:00:00+00:00     0.336164    1.675077    2.457727
# 2019-12-31 00:00:00+00:00     0.356973    1.147088    2.930893
#
#                            (roms - biasMET)_NO_OSC
# 2018-01-01 00:00:00+00:00                      NaN
# 2018-01-01 01:00:00+00:00                      NaN
# 2018-01-01 02:00:00+00:00                      NaN
# 2018-01-01 03:00:00+00:00                      NaN
# 2018-01-01 04:00:00+00:00                      NaN
# ...                                            ...
# 2019-12-30 20:00:00+00:00                 0.201782
# 2019-12-30 21:00:00+00:00                 0.305189
# 2019-12-30 22:00:00+00:00                 0.290741
# 2019-12-30 23:00:00+00:00                 0.188389
# 2019-12-31 00:00:00+00:00                 0.208885
#
# [17497 rows x 7 columns]
# df.index:  DatetimeIndex(['2018-01-01 00:00:00+00:00', '2018-01-01 01:00:00+00:00',
#                '2018-01-01 02:00:00+00:00', '2018-01-01 03:00:00+00:00',
#                '2018-01-01 04:00:00+00:00', '2018-01-01 05:00:00+00:00',
#                '2018-01-01 06:00:00+00:00', '2018-01-01 07:00:00+00:00',
#                '2018-01-01 08:00:00+00:00', '2018-01-01 09:00:00+00:00',
#                ...
#                '2019-12-30 15:00:00+00:00', '2019-12-30 16:00:00+00:00',
#                '2019-12-30 17:00:00+00:00', '2019-12-30 18:00:00+00:00',
#                '2019-12-30 19:00:00+00:00', '2019-12-30 20:00:00+00:00',
#                '2019-12-30 21:00:00+00:00', '2019-12-30 22:00:00+00:00',
#                '2019-12-30 23:00:00+00:00', '2019-12-31 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', length=17497, freq='H')
# Preparing Datarame with features and labels...
# list_all_variables:  ['obs', 'roms', 'u10', '(roms - biasMET) - (obs - tide_py)', 'wind_dir', 'msl', 'roms - (obs - tide_py)', 'wind_speed', '(obs - tide_py)', 'tide_py', '(roms - biasMET)', 'v10']
# Generating obs and tide_py DataFrame...
# Using already generated kyststasjoner file.
# oper_df:                             tide_py_NO_OSC  obs_NO_OSC
# 2018-01-01 00:00:00+00:00            0.73        0.88
# 2018-01-01 01:00:00+00:00            0.78        0.92
# 2018-01-01 02:00:00+00:00            0.82        0.96
# 2018-01-01 03:00:00+00:00            0.85        0.93
# 2018-01-01 04:00:00+00:00            0.82        0.86
# ...                                   ...         ...
# 2019-12-30 20:00:00+00:00            0.80        1.15
# 2019-12-30 21:00:00+00:00            0.76        1.11
# 2019-12-30 22:00:00+00:00            0.70        1.03
# 2019-12-30 23:00:00+00:00            0.65        0.98
# 2019-12-31 00:00:00+00:00            0.60        0.92
#
# [17221 rows x 2 columns]
# Load all data to memory at initialization, this may take a few seconds...
# crrt_df:                             obs_NO_OSC  tide_py_NO_OSC
# 2018-01-01 00:00:00+00:00       0.879        0.720640
# 2018-01-01 01:00:00+00:00       0.920        0.770725
# 2018-01-01 02:00:00+00:00       0.955        0.822309
# 2018-01-01 03:00:00+00:00       0.928        0.871667
# 2018-01-01 04:00:00+00:00       0.855        0.868962
# ...                               ...             ...
# 2019-12-30 20:00:00+00:00       1.155        0.849811
# 2019-12-30 21:00:00+00:00       1.111        0.825735
# 2019-12-30 22:00:00+00:00       1.036        0.769728
# 2019-12-30 23:00:00+00:00       0.978        0.715371
# 2019-12-31 00:00:00+00:00       0.927        0.669125
#
# [17497 rows x 2 columns]
# station:  NO_OSC  horizon:  1
# Added obs and tide data:
#                            obs_NO_OSC  tide_py_NO_OSC
# 2018-01-01 00:00:00+00:00       0.879        0.720640
# 2018-01-01 01:00:00+00:00       0.920        0.770725
# 2018-01-01 02:00:00+00:00       0.955        0.822309
# 2018-01-01 03:00:00+00:00       0.928        0.871667
# 2018-01-01 04:00:00+00:00       0.855        0.868962
# ...                               ...             ...
# 2019-12-30 20:00:00+00:00       1.155        0.849811
# 2019-12-30 21:00:00+00:00       1.111        0.825735
# 2019-12-30 22:00:00+00:00       1.036        0.769728
# 2019-12-30 23:00:00+00:00       0.978        0.715371
# 2019-12-31 00:00:00+00:00       0.927        0.669125
#
# [17497 rows x 2 columns]
# self.df_obs_tide in add_os_tide:                             obs_NO_OSC  tide_py_NO_OSC
# 2018-01-01 00:00:00+00:00       0.879        0.720640
# 2018-01-01 01:00:00+00:00       0.920        0.770725
# 2018-01-01 02:00:00+00:00       0.955        0.822309
# 2018-01-01 03:00:00+00:00       0.928        0.871667
# 2018-01-01 04:00:00+00:00       0.855        0.868962
# ...                               ...             ...
# 2019-12-30 20:00:00+00:00       1.155        0.849811
# 2019-12-30 21:00:00+00:00       1.111        0.825735
# 2019-12-30 22:00:00+00:00       1.036        0.769728
# 2019-12-30 23:00:00+00:00       0.978        0.715371
# 2019-12-31 00:00:00+00:00       0.927        0.669125
#
# [17497 rows x 2 columns]
# Adding (obs - tide_py) columns...
# Added (obs-tide) data
#                            (obs - tide_py)_NO_OSC
# 2018-01-01 00:00:00+00:00                0.158360
# 2018-01-01 01:00:00+00:00                0.149275
# 2018-01-01 02:00:00+00:00                0.132691
# 2018-01-01 03:00:00+00:00                0.056333
# 2018-01-01 04:00:00+00:00               -0.013962
# ...                                           ...
# 2019-12-30 20:00:00+00:00                0.305189
# 2019-12-30 21:00:00+00:00                0.285265
# 2019-12-30 22:00:00+00:00                0.266272
# 2019-12-30 23:00:00+00:00                0.262629
# 2019-12-31 00:00:00+00:00                0.257875
#
# [17497 rows x 1 columns]
# dfs:  [                           obs_NO_OSC  tide_py_NO_OSC
# 2018-01-01 00:00:00+00:00       0.879        0.720640
# 2018-01-01 01:00:00+00:00       0.920        0.770725
# 2018-01-01 02:00:00+00:00       0.955        0.822309
# 2018-01-01 03:00:00+00:00       0.928        0.871667
# 2018-01-01 04:00:00+00:00       0.855        0.868962
# ...                               ...             ...
# 2019-12-30 20:00:00+00:00       1.155        0.849811
# 2019-12-30 21:00:00+00:00       1.111        0.825735
# 2019-12-30 22:00:00+00:00       1.036        0.769728
# 2019-12-30 23:00:00+00:00       0.978        0.715371
# 2019-12-31 00:00:00+00:00       0.927        0.669125
#
# [17497 rows x 2 columns],                            (obs - tide_py)_NO_OSC
# 2018-01-01 00:00:00+00:00                0.158360
# 2018-01-01 01:00:00+00:00                0.149275
# 2018-01-01 02:00:00+00:00                0.132691
# 2018-01-01 03:00:00+00:00                0.056333
# 2018-01-01 04:00:00+00:00               -0.013962
# ...                                           ...
# 2019-12-30 20:00:00+00:00                0.305189
# 2019-12-30 21:00:00+00:00                0.285265
# 2019-12-30 22:00:00+00:00                0.266272
# 2019-12-30 23:00:00+00:00                0.262629
# 2019-12-31 00:00:00+00:00                0.257875
#
# [17497 rows x 1 columns]]
# Generating ROMS hindcast DataFrame...
# Added hindcast data:
#                            roms_NO_OSC
# time
# 2018-01-01 00:00:00+00:00     0.411663
# 2018-01-01 01:00:00+00:00     0.555702
# 2018-01-01 02:00:00+00:00     0.474306
# 2018-01-01 03:00:00+00:00     0.263965
# 2018-01-01 04:00:00+00:00     0.255458
# ...                                ...
# 2019-12-30 20:00:00+00:00     0.353680
# 2019-12-30 21:00:00+00:00     0.454468
# 2019-12-30 22:00:00+00:00     0.438253
# 2019-12-30 23:00:00+00:00     0.336164
# 2019-12-31 00:00:00+00:00     0.356973
#
# [17497 rows x 1 columns]
# Added meteorological data...
# Generating station forcing df...
# Added station forcing data:
#                               msl_NO_OSC  v10_NO_OSC  u10_NO_OSC
# time
# 2018-01-01 00:00:00+00:00   98446.898438    0.008046   -1.591091
# 2018-01-01 01:00:00+00:00   98380.343750    1.154886   -1.646257
# 2018-01-01 02:00:00+00:00   98362.156250    2.671098   -0.772317
# 2018-01-01 03:00:00+00:00   98331.765625    2.987844   -0.220661
# 2018-01-01 04:00:00+00:00   98307.585938    3.251965   -0.152914
# ...                                  ...         ...         ...
# 2019-12-30 20:00:00+00:00  100414.742188    1.913973    1.409484
# 2019-12-30 21:00:00+00:00  100413.296875    1.939072    1.316671
# 2019-12-30 22:00:00+00:00  100482.968750    1.835891    2.289390
# 2019-12-30 23:00:00+00:00  100529.296875    1.675077    2.457727
# 2019-12-31 00:00:00+00:00  100623.218750    1.147088    2.930893
#
# [16968 rows x 3 columns]
# Added roms - (obs - tide) data:
#                            roms - (obs - tide_py)_NO_OSC
# time
# 2018-01-01 00:00:00+00:00                       0.253303
# 2018-01-01 01:00:00+00:00                       0.406426
# 2018-01-01 02:00:00+00:00                       0.341616
# 2018-01-01 03:00:00+00:00                       0.207633
# 2018-01-01 04:00:00+00:00                       0.269420
# ...                                                  ...
# 2019-12-30 20:00:00+00:00                       0.048492
# 2019-12-30 21:00:00+00:00                       0.169204
# 2019-12-30 22:00:00+00:00                       0.171981
# 2019-12-30 23:00:00+00:00                       0.073535
# 2019-12-31 00:00:00+00:00                       0.099098
#
# [17497 rows x 1 columns]
# Duplicated indices in df_obs_tide:  <bound method Index.duplicated of DatetimeIndex(['2018-01-01 00:00:00+00:00', '2018-01-01 01:00:00+00:00',
#                '2018-01-01 02:00:00+00:00', '2018-01-01 03:00:00+00:00',
#                '2018-01-01 04:00:00+00:00', '2018-01-01 05:00:00+00:00',
#                '2018-01-01 06:00:00+00:00', '2018-01-01 07:00:00+00:00',
#                '2018-01-01 08:00:00+00:00', '2018-01-01 09:00:00+00:00',
#                ...
#                '2019-12-30 15:00:00+00:00', '2019-12-30 16:00:00+00:00',
#                '2019-12-30 17:00:00+00:00', '2019-12-30 18:00:00+00:00',
#                '2019-12-30 19:00:00+00:00', '2019-12-30 20:00:00+00:00',
#                '2019-12-30 21:00:00+00:00', '2019-12-30 22:00:00+00:00',
#                '2019-12-30 23:00:00+00:00', '2019-12-31 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', length=17497, freq='H')>
# Added (hindcast - biasMET) data:
#                            (roms - biasMET)_NO_OSC  \
# time
# 2018-01-01 00:00:00+00:00                      NaN
# 2018-01-01 01:00:00+00:00                      NaN
# 2018-01-01 02:00:00+00:00                      NaN
# 2018-01-01 03:00:00+00:00                      NaN
# 2018-01-01 04:00:00+00:00                      NaN
# ...                                            ...
# 2019-12-30 20:00:00+00:00                 0.201782
# 2019-12-30 21:00:00+00:00                 0.305189
# 2019-12-30 22:00:00+00:00                 0.290741
# 2019-12-30 23:00:00+00:00                 0.188389
# 2019-12-31 00:00:00+00:00                 0.208885
#
#                            (roms - biasMET) - (obs - tide_py)_NO_OSC
# time
# 2018-01-01 00:00:00+00:00                                        NaN
# 2018-01-01 01:00:00+00:00                                        NaN
# 2018-01-01 02:00:00+00:00                                        NaN
# 2018-01-01 03:00:00+00:00                                        NaN
# 2018-01-01 04:00:00+00:00                                        NaN
# ...                                                              ...
# 2019-12-30 20:00:00+00:00                                  -0.103407
# 2019-12-30 21:00:00+00:00                                   0.019924
# 2019-12-30 22:00:00+00:00                                   0.024469
# 2019-12-30 23:00:00+00:00                                  -0.074240
# 2019-12-31 00:00:00+00:00                                  -0.048990
#
# [17497 rows x 2 columns]
# Adding wind_speed columns...
# Adding wind_dir columns...
# Added wind data:
#                            wind_speed_NO_OSC  wind_dir_NO_OSC
# 2018-01-01 00:00:00+00:00           1.591112        -0.289751
# 2018-01-01 01:00:00+00:00           2.010951       -35.050522
# 2018-01-01 02:00:00+00:00           2.780510       -73.873383
# 2018-01-01 03:00:00+00:00           2.995981       -85.776207
# 2018-01-01 04:00:00+00:00           3.255558       -87.307823
# ...                                      ...              ...
# 2019-12-30 20:00:00+00:00           2.376960      -126.368591
# 2019-12-30 21:00:00+00:00           2.343848      -124.177338
# 2019-12-30 22:00:00+00:00           2.934587      -141.273422
# 2019-12-30 23:00:00+00:00           2.974274      -145.723404
# 2019-12-31 00:00:00+00:00           3.147371      -158.625702
#
# [17497 rows x 2 columns]
# Print each element in dfs list:
# 0
#                            obs_NO_OSC  tide_py_NO_OSC
# 2018-01-01 00:00:00+00:00       0.879        0.720640
# 2018-01-01 01:00:00+00:00       0.920        0.770725
# 2018-01-01 02:00:00+00:00       0.955        0.822309
# 2018-01-01 03:00:00+00:00       0.928        0.871667
# 2018-01-01 04:00:00+00:00       0.855        0.868962
# ...                               ...             ...
# 2019-12-30 20:00:00+00:00       1.155        0.849811
# 2019-12-30 21:00:00+00:00       1.111        0.825735
# 2019-12-30 22:00:00+00:00       1.036        0.769728
# 2019-12-30 23:00:00+00:00       0.978        0.715371
# 2019-12-31 00:00:00+00:00       0.927        0.669125
#
# [17497 rows x 2 columns]
# 1
#                            (obs - tide_py)_NO_OSC
# 2018-01-01 00:00:00+00:00                0.158360
# 2018-01-01 01:00:00+00:00                0.149275
# 2018-01-01 02:00:00+00:00                0.132691
# 2018-01-01 03:00:00+00:00                0.056333
# 2018-01-01 04:00:00+00:00               -0.013962
# ...                                           ...
# 2019-12-30 20:00:00+00:00                0.305189
# 2019-12-30 21:00:00+00:00                0.285265
# 2019-12-30 22:00:00+00:00                0.266272
# 2019-12-30 23:00:00+00:00                0.262629
# 2019-12-31 00:00:00+00:00                0.257875
#
# [17497 rows x 1 columns]
# 2
#                            roms_NO_OSC
# time
# 2018-01-01 00:00:00+00:00     0.411663
# 2018-01-01 01:00:00+00:00     0.555702
# 2018-01-01 02:00:00+00:00     0.474306
# 2018-01-01 03:00:00+00:00     0.263965
# 2018-01-01 04:00:00+00:00     0.255458
# ...                                ...
# 2019-12-30 20:00:00+00:00     0.353680
# 2019-12-30 21:00:00+00:00     0.454468
# 2019-12-30 22:00:00+00:00     0.438253
# 2019-12-30 23:00:00+00:00     0.336164
# 2019-12-31 00:00:00+00:00     0.356973
#
# [17497 rows x 1 columns]
# 3
#                               msl_NO_OSC  v10_NO_OSC  u10_NO_OSC
# time
# 2018-01-01 00:00:00+00:00   98446.898438    0.008046   -1.591091
# 2018-01-01 01:00:00+00:00   98380.343750    1.154886   -1.646257
# 2018-01-01 02:00:00+00:00   98362.156250    2.671098   -0.772317
# 2018-01-01 03:00:00+00:00   98331.765625    2.987844   -0.220661
# 2018-01-01 04:00:00+00:00   98307.585938    3.251965   -0.152914
# ...                                  ...         ...         ...
# 2019-12-30 20:00:00+00:00  100414.742188    1.913973    1.409484
# 2019-12-30 21:00:00+00:00  100413.296875    1.939072    1.316671
# 2019-12-30 22:00:00+00:00  100482.968750    1.835891    2.289390
# 2019-12-30 23:00:00+00:00  100529.296875    1.675077    2.457727
# 2019-12-31 00:00:00+00:00  100623.218750    1.147088    2.930893
#
# [16968 rows x 3 columns]
# 4
#                            roms - (obs - tide_py)_NO_OSC
# time
# 2018-01-01 00:00:00+00:00                       0.253303
# 2018-01-01 01:00:00+00:00                       0.406426
# 2018-01-01 02:00:00+00:00                       0.341616
# 2018-01-01 03:00:00+00:00                       0.207633
# 2018-01-01 04:00:00+00:00                       0.269420
# ...                                                  ...
# 2019-12-30 20:00:00+00:00                       0.048492
# 2019-12-30 21:00:00+00:00                       0.169204
# 2019-12-30 22:00:00+00:00                       0.171981
# 2019-12-30 23:00:00+00:00                       0.073535
# 2019-12-31 00:00:00+00:00                       0.099098
#
# [17497 rows x 1 columns]
# 5
#                            (roms - biasMET)_NO_OSC  \
# time
# 2018-01-01 00:00:00+00:00                      NaN
# 2018-01-01 01:00:00+00:00                      NaN
# 2018-01-01 02:00:00+00:00                      NaN
# 2018-01-01 03:00:00+00:00                      NaN
# 2018-01-01 04:00:00+00:00                      NaN
# ...                                            ...
# 2019-12-30 20:00:00+00:00                 0.201782
# 2019-12-30 21:00:00+00:00                 0.305189
# 2019-12-30 22:00:00+00:00                 0.290741
# 2019-12-30 23:00:00+00:00                 0.188389
# 2019-12-31 00:00:00+00:00                 0.208885
#
#                            (roms - biasMET) - (obs - tide_py)_NO_OSC
# time
# 2018-01-01 00:00:00+00:00                                        NaN
# 2018-01-01 01:00:00+00:00                                        NaN
# 2018-01-01 02:00:00+00:00                                        NaN
# 2018-01-01 03:00:00+00:00                                        NaN
# 2018-01-01 04:00:00+00:00                                        NaN
# ...                                                              ...
# 2019-12-30 20:00:00+00:00                                  -0.103407
# 2019-12-30 21:00:00+00:00                                   0.019924
# 2019-12-30 22:00:00+00:00                                   0.024469
# 2019-12-30 23:00:00+00:00                                  -0.074240
# 2019-12-31 00:00:00+00:00                                  -0.048990
#
# [17497 rows x 2 columns]
# 6
#                            wind_speed_NO_OSC  wind_dir_NO_OSC
# 2018-01-01 00:00:00+00:00           1.591112        -0.289751
# 2018-01-01 01:00:00+00:00           2.010951       -35.050522
# 2018-01-01 02:00:00+00:00           2.780510       -73.873383
# 2018-01-01 03:00:00+00:00           2.995981       -85.776207
# 2018-01-01 04:00:00+00:00           3.255558       -87.307823
# ...                                      ...              ...
# 2019-12-30 20:00:00+00:00           2.376960      -126.368591
# 2019-12-30 21:00:00+00:00           2.343848      -124.177338
# 2019-12-30 22:00:00+00:00           2.934587      -141.273422
# 2019-12-30 23:00:00+00:00           2.974274      -145.723404
# 2019-12-31 00:00:00+00:00           3.147371      -158.625702
#
# [17497 rows x 2 columns]
# df:                             obs_NO_OSC  tide_py_NO_OSC
# 2018-01-01 00:00:00+00:00       0.879        0.720640
# 2018-01-01 01:00:00+00:00       0.920        0.770725
# 2018-01-01 02:00:00+00:00       0.955        0.822309
# 2018-01-01 03:00:00+00:00       0.928        0.871667
# 2018-01-01 04:00:00+00:00       0.855        0.868962
# ...                               ...             ...
# 2019-12-30 20:00:00+00:00       1.155        0.849811
# 2019-12-30 21:00:00+00:00       1.111        0.825735
# 2019-12-30 22:00:00+00:00       1.036        0.769728
# 2019-12-30 23:00:00+00:00       0.978        0.715371
# 2019-12-31 00:00:00+00:00       0.927        0.669125
#
# [17497 rows x 2 columns]
# df:                             obs_NO_OSC  tide_py_NO_OSC  (obs - tide_py)_NO_OSC  \
# 2018-01-01 00:00:00+00:00       0.879        0.720640                0.158360
# 2018-01-01 01:00:00+00:00       0.920        0.770725                0.149275
# 2018-01-01 02:00:00+00:00       0.955        0.822309                0.132691
# 2018-01-01 03:00:00+00:00       0.928        0.871667                0.056333
# 2018-01-01 04:00:00+00:00       0.855        0.868962               -0.013962
# ...                               ...             ...                     ...
# 2019-12-30 20:00:00+00:00       1.155        0.849811                0.305189
# 2019-12-30 21:00:00+00:00       1.111        0.825735                0.285265
# 2019-12-30 22:00:00+00:00       1.036        0.769728                0.266272
# 2019-12-30 23:00:00+00:00       0.978        0.715371                0.262629
# 2019-12-31 00:00:00+00:00       0.927        0.669125                0.257875
#
#                            roms_NO_OSC     msl_NO_OSC  v10_NO_OSC  u10_NO_OSC  \
# 2018-01-01 00:00:00+00:00     0.411663   98446.898438    0.008046   -1.591091
# 2018-01-01 01:00:00+00:00     0.555702   98380.343750    1.154886   -1.646257
# 2018-01-01 02:00:00+00:00     0.474306   98362.156250    2.671098   -0.772317
# 2018-01-01 03:00:00+00:00     0.263965   98331.765625    2.987844   -0.220661
# 2018-01-01 04:00:00+00:00     0.255458   98307.585938    3.251965   -0.152914
# ...                                ...            ...         ...         ...
# 2019-12-30 20:00:00+00:00     0.353680  100414.742188    1.913973    1.409484
# 2019-12-30 21:00:00+00:00     0.454468  100413.296875    1.939072    1.316671
# 2019-12-30 22:00:00+00:00     0.438253  100482.968750    1.835891    2.289390
# 2019-12-30 23:00:00+00:00     0.336164  100529.296875    1.675077    2.457727
# 2019-12-31 00:00:00+00:00     0.356973  100623.218750    1.147088    2.930893
#
#                            roms - (obs - tide_py)_NO_OSC  \
# 2018-01-01 00:00:00+00:00                       0.253303
# 2018-01-01 01:00:00+00:00                       0.406426
# 2018-01-01 02:00:00+00:00                       0.341616
# 2018-01-01 03:00:00+00:00                       0.207633
# 2018-01-01 04:00:00+00:00                       0.269420
# ...                                                  ...
# 2019-12-30 20:00:00+00:00                       0.048492
# 2019-12-30 21:00:00+00:00                       0.169204
# 2019-12-30 22:00:00+00:00                       0.171981
# 2019-12-30 23:00:00+00:00                       0.073535
# 2019-12-31 00:00:00+00:00                       0.099098
#
#                            (roms - biasMET)_NO_OSC  \
# 2018-01-01 00:00:00+00:00                      NaN
# 2018-01-01 01:00:00+00:00                      NaN
# 2018-01-01 02:00:00+00:00                      NaN
# 2018-01-01 03:00:00+00:00                      NaN
# 2018-01-01 04:00:00+00:00                      NaN
# ...                                            ...
# 2019-12-30 20:00:00+00:00                 0.201782
# 2019-12-30 21:00:00+00:00                 0.305189
# 2019-12-30 22:00:00+00:00                 0.290741
# 2019-12-30 23:00:00+00:00                 0.188389
# 2019-12-31 00:00:00+00:00                 0.208885
#
#                            (roms - biasMET) - (obs - tide_py)_NO_OSC  \
# 2018-01-01 00:00:00+00:00                                        NaN
# 2018-01-01 01:00:00+00:00                                        NaN
# 2018-01-01 02:00:00+00:00                                        NaN
# 2018-01-01 03:00:00+00:00                                        NaN
# 2018-01-01 04:00:00+00:00                                        NaN
# ...                                                              ...
# 2019-12-30 20:00:00+00:00                                  -0.103407
# 2019-12-30 21:00:00+00:00                                   0.019924
# 2019-12-30 22:00:00+00:00                                   0.024469
# 2019-12-30 23:00:00+00:00                                  -0.074240
# 2019-12-31 00:00:00+00:00                                  -0.048990
#
#                            wind_speed_NO_OSC  wind_dir_NO_OSC
# 2018-01-01 00:00:00+00:00           1.591112        -0.289751
# 2018-01-01 01:00:00+00:00           2.010951       -35.050522
# 2018-01-01 02:00:00+00:00           2.780510       -73.873383
# 2018-01-01 03:00:00+00:00           2.995981       -85.776207
# 2018-01-01 04:00:00+00:00           3.255558       -87.307823
# ...                                      ...              ...
# 2019-12-30 20:00:00+00:00           2.376960      -126.368591
# 2019-12-30 21:00:00+00:00           2.343848      -124.177338
# 2019-12-30 22:00:00+00:00           2.934587      -141.273422
# 2019-12-30 23:00:00+00:00           2.974274      -145.723404
# 2019-12-31 00:00:00+00:00           3.147371      -158.625702
#
# [17497 rows x 12 columns]
# df.index:  DatetimeIndex(['2018-01-01 00:00:00+00:00', '2018-01-01 01:00:00+00:00',
#                '2018-01-01 02:00:00+00:00', '2018-01-01 03:00:00+00:00',
#                '2018-01-01 04:00:00+00:00', '2018-01-01 05:00:00+00:00',
#                '2018-01-01 06:00:00+00:00', '2018-01-01 07:00:00+00:00',
#                '2018-01-01 08:00:00+00:00', '2018-01-01 09:00:00+00:00',
#                ...
#                '2019-12-30 15:00:00+00:00', '2019-12-30 16:00:00+00:00',
#                '2019-12-30 17:00:00+00:00', '2019-12-30 18:00:00+00:00',
#                '2019-12-30 19:00:00+00:00', '2019-12-30 20:00:00+00:00',
#                '2019-12-30 21:00:00+00:00', '2019-12-30 22:00:00+00:00',
#                '2019-12-30 23:00:00+00:00', '2019-12-31 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', length=17497, freq='H')
# Index(['obs_NO_OSC', 'tide_py_NO_OSC', '(obs - tide_py)_NO_OSC', 'roms_NO_OSC',
#        'msl_NO_OSC', 'v10_NO_OSC', 'u10_NO_OSC',
#        'roms - (obs - tide_py)_NO_OSC', '(roms - biasMET)_NO_OSC',
#        '(roms - biasMET) - (obs - tide_py)_NO_OSC', 'wind_speed_NO_OSC',
#        'wind_dir_NO_OSC'],
#       dtype='object')
#                            obs_NO_OSC  tide_py_NO_OSC  (obs - tide_py)_NO_OSC  \
# 2018-01-01 00:00:00+00:00       0.879        0.720640                0.158360
# 2018-01-01 01:00:00+00:00       0.920        0.770725                0.149275
# 2018-01-01 02:00:00+00:00       0.955        0.822309                0.132691
# 2018-01-01 03:00:00+00:00       0.928        0.871667                0.056333
# 2018-01-01 04:00:00+00:00       0.855        0.868962               -0.013962
#
#                            roms_NO_OSC    msl_NO_OSC  v10_NO_OSC  u10_NO_OSC  \
# 2018-01-01 00:00:00+00:00     0.411663  98446.898438    0.008046   -1.591091
# 2018-01-01 01:00:00+00:00     0.555702  98380.343750    1.154886   -1.646257
# 2018-01-01 02:00:00+00:00     0.474306  98362.156250    2.671098   -0.772317
# 2018-01-01 03:00:00+00:00     0.263965  98331.765625    2.987844   -0.220661
# 2018-01-01 04:00:00+00:00     0.255458  98307.585938    3.251965   -0.152914
#
#                            roms - (obs - tide_py)_NO_OSC  \
# 2018-01-01 00:00:00+00:00                       0.253303
# 2018-01-01 01:00:00+00:00                       0.406426
# 2018-01-01 02:00:00+00:00                       0.341616
# 2018-01-01 03:00:00+00:00                       0.207633
# 2018-01-01 04:00:00+00:00                       0.269420
#
#                            (roms - biasMET)_NO_OSC  \
# 2018-01-01 00:00:00+00:00                      NaN
# 2018-01-01 01:00:00+00:00                      NaN
# 2018-01-01 02:00:00+00:00                      NaN
# 2018-01-01 03:00:00+00:00                      NaN
# 2018-01-01 04:00:00+00:00                      NaN
#
#                            (roms - biasMET) - (obs - tide_py)_NO_OSC  \
# 2018-01-01 00:00:00+00:00                                        NaN
# 2018-01-01 01:00:00+00:00                                        NaN
# 2018-01-01 02:00:00+00:00                                        NaN
# 2018-01-01 03:00:00+00:00                                        NaN
# 2018-01-01 04:00:00+00:00                                        NaN
#
#                            wind_speed_NO_OSC  wind_dir_NO_OSC
# 2018-01-01 00:00:00+00:00           1.591112        -0.289751
# 2018-01-01 01:00:00+00:00           2.010951       -35.050522
# 2018-01-01 02:00:00+00:00           2.780510       -73.873383
# 2018-01-01 03:00:00+00:00           2.995981       -85.776207
# 2018-01-01 04:00:00+00:00           3.255558       -87.307823

# %%
data_dir = (
        '/lustre/storeB/users/paulinast'
        +'/polar_plots_operational'
        )

# data_dir = 'rp_figs'

# %%
station = 'NO_OSC'

# %%
eda = EDA(station, data_dir, df)

# %%
fun = 'mean'
var1 = '(roms - biasMET)'# 'stormsurge_corrected'
var2 = '(obs - tide_py)' #'(obs_tide_py)'

# %%
sorted_df, aggregated_df, c, theta, rho = eda.radial_plot_data(
                 function_name=fun,  
                 var1=var1, 
                 var2=var2, 
                 radial_coord_name='wind_speed',  # swh (waves)
                 angular_coord_name='wind_dir',  # mwd (waves)
                #  round_rho_val=1, 
                #  round_theta_val=10
                 )
# Out:
# aggregated_df:                                             correctionRP_NO_OSC
# wind_speed_bin_NO_OSC wind_dir_bin_NO_OSC
# 0.0                   -180.0                          0.036788
#                       -170.0                         -0.014309
#                       -160.0                         -0.034919
#                       -150.0                         -0.026656
#                       -140.0                         -0.033424
# ...                                                        ...
# 8.0                   -80.0                          -0.069044
#                       -70.0                          -0.191465
# 9.0                   -100.0                         -0.045886
#                       -90.0                          -0.061713
#                       -80.0                           0.033597
#
# [277 rows x 1 columns]
# aggregated_df_count:                                             count_NO_OSC
# wind_speed_bin_NO_OSC wind_dir_bin_NO_OSC
# 0.0                   -180.0                          4
#                       -170.0                         10
#                       -160.0                          9
#                       -150.0                          6
#                       -140.0                         11
# ...                                                 ...
# 8.0                   -80.0                           5
#                       -70.0                           1
# 9.0                   -100.0                          1
#                       -90.0                           1
#                       -80.0                           1
#
# [277 rows x 1 columns]
# aggregated_df:                                             correctionRP_NO_OSC
# wind_speed_bin_NO_OSC wind_dir_bin_NO_OSC
# 0.0                   -180.0                          0.036788
#                       -170.0                         -0.014309
#                       -160.0                         -0.034919
#                       -150.0                         -0.026656
#                       -140.0                         -0.033424
# ...                                                        ...
# 8.0                   -80.0                          -0.069044
#                       -70.0                          -0.191465
# 9.0                   -100.0                         -0.045886
#                       -90.0                          -0.061713
#                       -80.0                           0.033597
#
# [277 rows x 1 columns]

# %%
path_rp = eda.make_radial_plot_path(
                 fun, 
                 station, 
                 roms_dataset='operational_arome_t0', 
                 var1=var1, 
                 var2=var2, 
                 polar_coordinates='wind'
                 )

# %%
abs_max = np.abs(np.max(np.nanquantile(c, 0.95)))
abs_min = np.abs(np.min(np.nanquantile(c, 0.05)))
vmax = max(abs_max, abs_min)
vmin = - vmax

# %%
eda.radial_plot(
     c, 
     np.transpose(theta), 
     np.transpose(rho), 
     fun, 
     var1, 
     var2, 
     vmax=vmax,
     vmin=vmin,
     path=path_rp
)
# Out:
# Saving polar plots...
# /lustre/storeB/users/paulinast/polar_plots_operational/radial_plots/mean/roms-biasMET_obs-tide_py/radial_plot_wind/radial_plot_wind_operational_arome_t0_NO_OSC_mean_roms-biasMET_obs-tide_py_2018-01-01_2019-12-31.png

# %% [markdown]
# # ------------------ OBS: Need to add  the older version of the polar plot function with round_rho_val arg!!! -------------------
#
# The code below does not work!

# %% [markdown]
# ## Coarser resolution

# %%
sorted_df, aggregated_df, c, theta, rho = eda.radial_plot_data(
                 function_name=fun,  
                 var1=var1, 
                 var2=var2, 
                 radial_coord_name='wind_speed',  # swh
                 angular_coord_name='wind_dir',  # mwd
                 min_obs_bin=3,
                 round_rho_val=2, 
                 round_theta_val=30
                 )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [24], line 1
# ----> 1 sorted_df, aggregated_df, c, theta, rho = eda.radial_plot_data(
#       2                  function_name=fun,
#       3                  var1=var1,
#       4                  var2=var2,
#       5                  radial_coord_name='wind_speed',  # swh
#       6                  angular_coord_name='wind_dir',  # mwd
#       7                  min_obs_bin=3,
#       8                  round_rho_val=2,
#       9                  round_theta_val=30
#      10                  )
#
# TypeError: radial_plot_data() got an unexpected keyword argument 'round_rho_val'

# %%
path_rp = eda.make_radial_plot_path(
                 fun, 
                 station, 
                 roms_dataset='operational_arome_t0', 
                 var1=var1, 
                 var2=var2, 
                 polar_coordinates='wind'
                 )

# %%
abs_max = np.abs(np.max(np.nanquantile(c, 0.95)))
abs_min = np.abs(np.min(np.nanquantile(c, 0.05)))
vmax = max(abs_max, abs_min)
vmin = - vmax

# %%
eda.radial_plot(
     c, 
     np.transpose(theta), 
     np.transpose(rho), 
     fun, 
     var1, 
     var2, 
     vmax=vmax,
     vmin=vmin,
     path=path_rp
)
# Out:
# c.shape:  (120, 5)
# theta.shape:  (120, 5)
# np.max(np.max(rho)):  9.0
# rho[0, 0] - rho[0, 1]:  -2.0
# Saving polar plots...
# rp_figs/radial_plots/mean/roms-biasMET_obs-tide_py/radial_plot_wind/radial_plot_wind_operational_arome_t0_NO_OSC_mean_roms-biasMET_obs-tide_py_2001-01-01_2019-12-31.png

# %%
sorted_df, aggregated_df, c, theta, rho = eda.radial_plot_data(
                 function_name=fun,  
                 var1=var1, 
                 var2=var2, 
                 radial_coord_name='wind_speed',  # swh
                 angular_coord_name='wind_dir',  # mwd
                 round_rho_val=1, 
                 round_theta_val=10,
                 min_obs_bin=5
                 )
# Out:
# aggregated_df:                                             correctionRP_NO_OSC
# wind_speed_bin_NO_OSC wind_dir_bin_NO_OSC
# 1.0                   -170.0                         -0.003183
#                       -160.0                         -0.004687
#                       -150.0                         -0.023573
#                       -140.0                         -0.010403
#                       -130.0                         -0.020672
# ...                                                        ...
# 8.0                    140.0                         -0.055241
# 9.0                   -100.0                         -0.045886
#                       -90.0                          -0.061713
#                       -80.0                           0.192546
#                       -70.0                           0.033597
#
# [251 rows x 1 columns]
# aggregated_df_count:                                             count_NO_OSC
# wind_speed_bin_NO_OSC wind_dir_bin_NO_OSC
# 1.0                   -170.0                         32
#                       -160.0                         37
#                       -150.0                         44
#                       -140.0                         26
#                       -130.0                         38
# ...                                                 ...
# 8.0                    140.0                          1
# 9.0                   -100.0                          1
#                       -90.0                           1
#                       -80.0                           1
#                       -70.0                           1
#
# [251 rows x 1 columns]
# aggregated_df:                                             correctionRP_NO_OSC
# wind_speed_bin_NO_OSC wind_dir_bin_NO_OSC
# 1.0                   -170.0                         -0.003183
#                       -160.0                         -0.004687
#                       -150.0                         -0.023573
#                       -140.0                         -0.010403
#                       -130.0                         -0.020672
# ...                                                        ...
# 8.0                    140.0                               NaN
# 9.0                   -100.0                               NaN
#                       -90.0                                NaN
#                       -80.0                                NaN
#                       -70.0                                NaN
#
# [251 rows x 1 columns]
# unique_directions:  Float64Index([ -2.9670597283903604,   -2.792526803190927,  -2.6179938779914944,
#                 -2.443460952792061,  -2.2689280275926285,  -2.0943951023931953,
#                -1.9198621771937625,  -1.7453292519943295,  -1.5707963267948966,
#                -1.3962634015954636,  -1.2217304763960306,  -1.0471975511965976,
#                -0.8726646259971648,  -0.6981317007977318,  -0.5235987755982988,
#                -0.3490658503988659, -0.17453292519943295,                 -0.0,
#                0.17453292519943295,   0.3490658503988659,   0.5235987755982988,
#                 0.6981317007977318,   0.8726646259971648,   1.0471975511965976,
#                 1.2217304763960306,   1.3962634015954636,   1.5707963267948966,
#                 1.7453292519943295,   1.9198621771937625,   2.0943951023931953,
#                 2.2689280275926285,    2.443460952792061,   2.6179938779914944,
#                  2.792526803190927,   2.9670597283903604,
#                  3.141592653589793],
#              dtype='float64', name='wind_dir_bin_NO_OSC')
# len(unique_directions):  36
# unique_directions_high_res:  [-3.14159265 -3.12409074 -3.10658884 -3.08908693 -3.07158502 -3.05408311
#  -3.0365812  -3.01907929 -3.00157738 -2.98407547 -2.96657356 -2.94907166
#  -2.93156975 -2.91406784 -2.89656593 -2.87906402 -2.86156211 -2.8440602
#  -2.82655829 -2.80905638 -2.79155447 -2.77405257 -2.75655066 -2.73904875
#  -2.72154684 -2.70404493 -2.68654302 -2.66904111 -2.6515392  -2.63403729
#  -2.61653539 -2.59903348 -2.58153157 -2.56402966 -2.54652775 -2.52902584
#  -2.51152393 -2.49402202 -2.47652011 -2.45901821 -2.4415163  -2.42401439
#  -2.40651248 -2.38901057 -2.37150866 -2.35400675 -2.33650484 -2.31900293
#  -2.30150102 -2.28399912 -2.26649721 -2.2489953  -2.23149339 -2.21399148
#  -2.19648957 -2.17898766 -2.16148575 -2.14398384 -2.12648194 -2.10898003
#  -2.09147812 -2.07397621 -2.0564743  -2.03897239 -2.02147048 -2.00396857
#  -1.98646666 -1.96896476 -1.95146285 -1.93396094 -1.91645903 -1.89895712
#  -1.88145521 -1.8639533  -1.84645139 -1.82894948 -1.81144757 -1.79394567
#  -1.77644376 -1.75894185 -1.74143994 -1.72393803 -1.70643612 -1.68893421
#  -1.6714323  -1.65393039 -1.63642849 -1.61892658 -1.60142467 -1.58392276
#  -1.56642085 -1.54891894 -1.53141703 -1.51391512 -1.49641321 -1.4789113
#  -1.4614094  -1.44390749 -1.42640558 -1.40890367 -1.39140176 -1.37389985
#  -1.35639794 -1.33889603 -1.32139412 -1.30389222 -1.28639031 -1.2688884
#  -1.25138649 -1.23388458 -1.21638267 -1.19888076 -1.18137885 -1.16387694
#  -1.14637504 -1.12887313 -1.11137122 -1.09386931 -1.0763674  -1.05886549
#  -1.04136358 -1.02386167 -1.00635976 -0.98885785 -0.97135595 -0.95385404
#  -0.93635213 -0.91885022 -0.90134831 -0.8838464  -0.86634449 -0.84884258
#  -0.83134067 -0.81383877 -0.79633686 -0.77883495 -0.76133304 -0.74383113
#  -0.72632922 -0.70882731 -0.6913254  -0.67382349 -0.65632159 -0.63881968
#  -0.62131777 -0.60381586 -0.58631395 -0.56881204 -0.55131013 -0.53380822
#  -0.51630631 -0.4988044  -0.4813025  -0.46380059 -0.44629868 -0.42879677
#  -0.41129486 -0.39379295 -0.37629104 -0.35878913 -0.34128722 -0.32378532
#  -0.30628341 -0.2887815  -0.27127959 -0.25377768 -0.23627577 -0.21877386
#  -0.20127195 -0.18377004 -0.16626813 -0.14876623 -0.13126432 -0.11376241
#  -0.0962605  -0.07875859 -0.06125668 -0.04375477 -0.02625286 -0.00875095
#   0.00875095  0.02625286  0.04375477  0.06125668  0.07875859  0.0962605
#   0.11376241  0.13126432  0.14876623  0.16626813  0.18377004  0.20127195
#   0.21877386  0.23627577  0.25377768  0.27127959  0.2887815   0.30628341
#   0.32378532  0.34128722  0.35878913  0.37629104  0.39379295  0.41129486
#   0.42879677  0.44629868  0.46380059  0.4813025   0.4988044   0.51630631
#   0.53380822  0.55131013  0.56881204  0.58631395  0.60381586  0.62131777
#   0.63881968  0.65632159  0.67382349  0.6913254   0.70882731  0.72632922
#   0.74383113  0.76133304  0.77883495  0.79633686  0.81383877  0.83134067
#   0.84884258  0.86634449  0.8838464   0.90134831  0.91885022  0.93635213
#   0.95385404  0.97135595  0.98885785  1.00635976  1.02386167  1.04136358
#   1.05886549  1.0763674   1.09386931  1.11137122  1.12887313  1.14637504
#   1.16387694  1.18137885  1.19888076  1.21638267  1.23388458  1.25138649
#   1.2688884   1.28639031  1.30389222  1.32139412  1.33889603  1.35639794
#   1.37389985  1.39140176  1.40890367  1.42640558  1.44390749  1.4614094
#   1.4789113   1.49641321  1.51391512  1.53141703  1.54891894  1.56642085
#   1.58392276  1.60142467  1.61892658  1.63642849  1.65393039  1.6714323
#   1.68893421  1.70643612  1.72393803  1.74143994  1.75894185  1.77644376
#   1.79394567  1.81144757  1.82894948  1.84645139  1.8639533   1.88145521
#   1.89895712  1.91645903  1.93396094  1.95146285  1.96896476  1.98646666
#   2.00396857  2.02147048  2.03897239  2.0564743   2.07397621  2.09147812
#   2.10898003  2.12648194  2.14398384  2.16148575  2.17898766  2.19648957
#   2.21399148  2.23149339  2.2489953   2.26649721  2.28399912  2.30150102
#   2.31900293  2.33650484  2.35400675  2.37150866  2.38901057  2.40651248
#   2.42401439  2.4415163   2.45901821  2.47652011  2.49402202  2.51152393
#   2.52902584  2.54652775  2.56402966  2.58153157  2.59903348  2.61653539
#   2.63403729  2.6515392   2.66904111  2.68654302  2.70404493  2.72154684
#   2.73904875  2.75655066  2.77405257  2.79155447  2.80905638  2.82655829
#   2.8440602   2.86156211  2.87906402  2.89656593  2.91406784  2.93156975
#   2.94907166  2.96657356  2.98407547  3.00157738  3.01907929  3.0365812
#   3.05408311  3.07158502  3.08908693  3.10658884  3.12409074  3.14159265]
# np.radians(self.round_theta_val/(subdivs*2.)):  0.008726646259971648

# %%
abs_max = np.abs(np.max(np.nanquantile(c, 0.95)))
abs_min = np.abs(np.min(np.nanquantile(c, 0.05)))
vmax = max(abs_max, abs_min)
vmin = - vmax

# %%
eda.radial_plot(
     c, 
     np.transpose(theta), 
     np.transpose(rho), 
     fun, 
     var1, 
     var2, 
     vmax=0.05, #vmax,
     vmin=-0.05, #vmin,
     path=path_rp,
     cbar_label='Average residuals [m]', 
     xticks=np.arange(0, 2*np.pi, np.radians(30)),
     yticks = np.arange(0, 10, 3),
     add_colorbar=False
)
# Out:
# c.shape:  (360, 9)
# theta.shape:  (360, 9)
# np.max(np.max(rho)):  8.5
# rho[0, 0] - rho[0, 1]:  -1.0
# Saving polar plots...
# rp_figs/radial_plots/mean/roms-biasMET_obs-tide_py/radial_plot_wind/radial_plot_wind_operational_arome_t0_NO_OSC_mean_roms-biasMET_obs-tide_py_2001-01-01_2019-12-31.png
