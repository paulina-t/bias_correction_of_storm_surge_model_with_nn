# %%
import datetime as dt
import pytz
from ml_storm_surge_operational.mains.main_predict import main
# Out:
# 2025-05-25 12:16:35.835124: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
datetime_predict = '2025-05-19 00:00'
datetime_predict = (
        dt.datetime
        .strptime(datetime_predict, "%Y-%m-%d %H:%M")
        .replace(tzinfo=pytz.UTC)
    )
datetime_predict
# Out:
# datetime.datetime(2025, 5, 19, 0, 0, tzinfo=<UTC>)

# %%
main(datetime_predict)
# Out:
# --- station: NO_OSC
# Call PrepareDataFrames...
# Preparing feature and label df...
# Preparing auxiliary DataFrame...
# Generating obs and tide_py DataFrame form operational data for the past...
# var: observed_at_chartdatum
# path_list[i]: /lustre/storeB/project/metproduction/products/util/vannstand//kyststasjoner_norge.nc2025051800
# i: 0 j: 0 start:  0 end:  144 var: observed_at_chartdatum
# [0.36999997 0.30999997 0.30999997 0.34999996 0.39999998 0.40999997
#  0.45999998 0.53999996 0.59       0.57       0.51       0.43999997
#  0.37999997 0.32       0.29       0.29999998 0.33999997 0.35999998
#  0.37999997 0.43999997 0.51       0.53999996 0.53       0.48999998]
# var: observed_at_chartdatum
# path_list[i]: /lustre/storeB/project/metproduction/products/util/vannstand//kyststasjoner_norge.nc2025051800
# i: 0 j: 1 start:  6 end:  150 var: observed_at_chartdatum
# [0.30999997 0.30999997 0.34999996 0.39999998 0.40999997 0.45999998
# ...
